# %%
import pandas as pd
df = pd.DataFrame({'Chips':['Simba', 'Lays', 'Nicknaks', 'Doritos', 'Fritos',],'Quantity':[20, 10, 15, 25, 35,], 'Selling Price': [12,10, 15, 19, 24,],})
df
# Out:
#       Chips  Quantity  Selling Price
# 0     Simba        20             12
# 1      Lays        10             10
# 2  Nicknaks        15             15
# 3   Doritos        25             19
# 4    Fritos        35             24

# %%
import pandas as pd
df = pd.DataFrame({'CoolDrinks':['Coke', 'Fanta', 'Sprite', 'Schweppes', 'Jive',],'Quantity':[10,12,14,20,20], 'Selling Price': [19,16,15,17,20,],})
df
# Out:
#   CoolDrinks  Quantity  Selling Price
# 0       Coke        10             19
# 1      Fanta        12             16
# 2     Sprite        14             15
# 3  Schweppes        20             17
# 4       Jive        20             20

# %%
import pandas as pd
df = pd.DataFrame({'Chocolates':['Cadbury', 'Tex', 'KitKat', 'LunchBar', 'PS',],'Quantity':[20, 10, 15, 25, 35], 'Selling Price': [12,10, 15, 19, 24,],})
df
# Out:
#   Chocolates  Quantity  Selling Price
# 0    Cadbury        20             12
# 1        Tex        10             10
# 2     KitKat        15             15
# 3   LunchBar        25             19
# 4         PS        35             24

# %%
import pandas as pd
df = pd.DataFrame({'Pies':['Pepper Steak', 'Chicken', 'SteakandKidney', 'CheeseBurger', 'Pumpkin',],'Quantity':[20, 10, 15, 25, 35,], 'Selling Price': [12,10, 15, 19, 24],})
df
# Out:
#              Pies  Quantity  Selling Price
# 0    Pepper Steak        20             12
# 1         Chicken        10             10
# 2  SteakandKidney        15             15
# 3    CheeseBurger        25             19
# 4         Pumpkin        35             24

# %%
import pandas as pd
df = pd.DataFrame({'Fruit':['Pear', 'Apple', 'Orange', 'Grapes', 'Peach',],'Quantity':[20, 10, 15, 25, 35,], 'Selling Price': [12,10, 15, 19, 24,],})
df
# Out:
#     Fruit  Quantity  Selling Price
# 0    Pear        20             12
# 1   Apple        10             10
# 2  Orange        15             15
# 3  Grapes        25             19
# 4   Peach        35             24

# %%
import pandas as pd
df = pd.DataFrame({'Cupcakes':['Vanilla', 'Chocolate', 'RedVelvet', 'Carrot', 'Lemon',],'Quantity':[20, 10, 15, 25, 35,], 'Selling Price': [12,10, 15, 19, 24],})
df
# Out:
#     Cupcakes  Quantity  Selling Price
# 0    Vanilla        20             12
# 1  Chocolate        10             10
# 2  RedVelvet        15             15
# 3     Carrot        25             19
# 4      Lemon        35             24

# %%
import pandas as pd
df = pd.DataFrame({'Veggies':['Spinach', 'Cabbage', 'Carrot', 'Potatoes', 'Broccoli'],'Quantity':[20, 10, 15, 25, 35], 'Selling Price': [12,10, 15, 19, 24,],})
df
# Out:
#     Veggies  Quantity  Selling Price
# 0   Spinach        20             12
# 1   Cabbage        10             10
# 2    Carrot        15             15
# 3  Potatoes        25             19
# 4  Broccoli        35             24

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
ax = df.plot.bar(x='lab', y='val', rot=0)
df
# Out:
#   lab  val
# 0   A   10
# 1   B   30
# 2   C   20
